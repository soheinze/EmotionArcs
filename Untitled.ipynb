# %% [markdown]
# Viz_Test

# %%
import pandas as pd
import numpy as np
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot, iplot

# %%
import chart_studio.plotly as py

# %%
# %matplotlib inline

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0  -0.190764  0.518133 -1.337233 -0.494272
# 1   0.533471  1.888450 -1.796284 -1.505885
# 2   1.462530 -0.705068  1.166549 -2.088583
# 3   0.622819  0.531894 -1.087102  0.825909
# 4  -1.745588 -3.004529  0.583920  0.076464
# ..       ...       ...       ...       ...
# 95  0.001413  0.375108 -0.898297  0.507903
# 96  0.723187  1.878164  0.477365 -0.607081
# 97 -1.029863  1.804648  0.588945  0.405823
# 98  0.252533  1.059785 -0.828397 -0.827748
# 99 -0.529000  1.418851  0.574667 -0.385925
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()

# %%
df.iplot(kind='scatter', x='A',y='B', mode='markers',size=5)

# %%
df2.iplot(kind='bar', x='Category', y='Values')

# %%
df
# Out:
#            A         B         C         D
# 0  -0.190764  0.518133 -1.337233 -0.494272
# 1   0.533471  1.888450 -1.796284 -1.505885
# 2   1.462530 -0.705068  1.166549 -2.088583
# 3   0.622819  0.531894 -1.087102  0.825909
# 4  -1.745588 -3.004529  0.583920  0.076464
# ..       ...       ...       ...       ...
# 95  0.001413  0.375108 -0.898297  0.507903
# 96  0.723187  1.878164  0.477365 -0.607081
# 97 -1.029863  1.804648  0.588945  0.405823
# 98  0.252533  1.059785 -0.828397 -0.827748
# 99 -0.529000  1.418851  0.574667 -0.385925
#
# [100 rows x 4 columns]

# %%
df.sum().iplot(kind='bar')

# %%
df.iplot(kind='box')

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')

# %%
df.iplot(kind='hist', bins=25, barmode='stack' )

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# /opt/anaconda3/envs/drama/lib/python3.8/site-packages/cufflinks/plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# /opt/anaconda3/envs/drama/lib/python3.8/site-packages/cufflinks/plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')

# %%
df.scatter_matrix()

# %%
datapoints = [1,2,1,3,4,2,1,2,4,2,4,1]

# %%
datapoints
# Out:
# [1, 2, 1, 3, 4, 2, 1, 2, 4, 2, 4, 1]

# %% [markdown]
# Plot einer Liste mit Pseudozeitleiste

# %%
import plotly.express as px
fig = px.scatter(x=[i/len(datapoints) for i in range(0,len(datapoints))], y=datapoints)
fig.show()

# %%
t = np.linspace(0, 10, 100)

# %%
t
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
test_df = pd.read_csv('soundtracksData.csv')

# %%
test_df.columns
# Out:
# Index(['album_type', 'artists', 'available_markets', 'external_urls', 'href',
#        'id', 'images', 'name', 'release_date', 'release_date_precision',
#        'total_tracks', 'type', 'uri', 'reduced_title', 'valence_list',
#        'energy_list', 'genres'],
#       dtype='object')

# %%
import json

# %%
test_df['valence_list'] = test_df['valence_list'].apply(json.loads)

# %%
test_df['energy_list'] = test_df['energy_list'].apply(json.loads)

# %%
bool_series = test_df['genres'].str.contains("Family")
filtered_df = test_df[bool_series]
filtered_df.reset_index(drop=True,inplace=True)

# %%
filtered_df['valence_list']
# Out:
# 0      [0.195, 0.299, 0.274, 0.434, 0.311, 0.293, 0.1...
# 1      [0.188, 0.18, 0.748, 0.108, 0.391, 0.231, 0.67...
# 2      [0.191, 0.166, 0.43, 0.537, 0.371, 0.409, 0.68...
# 3      [0.341, 0.7, 0.595, 0.592, 0.567, 0.173, 0.65,...
# 4      [0.709, 0.415, 0.8, 0.489, 0.783, 0.309, 0.803...
#                              ...
# 172    [0.558, 0.0536, 0.0613, 0.114, 0.121, 0.136, 0...
# 173    [0.0413, 0.0871, 0.0377, 0.0392, 0.0543, 0.048...
# 174    [0.069, 0.124, 0.04, 0.0389, 0.0329, 0.187, 0....
# 175    [0.592, 0.591, 0.672, 0.622, 0.932, 0.596, 0.5...
# 176    [0.167, 0.134, 0.0854, 0.225, 0.0386, 0.108, 0...
# Name: valence_list, Length: 177, dtype: object

# %%
x_list = []
y_list = []

for f_list in filtered_df['valence_list']:
    for i,value in enumerate(f_list):
        x_list.append(i/len(f_list))
        y_list.append(value)

# %%
px.scatter(x=x_list,y=y_list)

# %%
from numpy import array
from numpy.random import rand

# multivariate time series data: (N = 1, variables = 5)
X = [rand(20,5)]

# %%
X
# Out:
# [array([[0.77211916, 0.47496279, 0.69931403, 0.64163852, 0.25334777],
#         [0.35295227, 0.86505228, 0.91388136, 0.55272356, 0.96975604],
#         [0.04181629, 0.4671408 , 0.37156897, 0.07221948, 0.78335953],
#         [0.8649036 , 0.32682375, 0.7083203 , 0.70018157, 0.49863341],
#         [0.78830509, 0.06002343, 0.66038448, 0.87114447, 0.03986232],
#         [0.24668932, 0.40746318, 0.86642566, 0.79946525, 0.06072189],
#         [0.30984828, 0.24695979, 0.6859296 , 0.78071919, 0.16935352],
#         [0.52815855, 0.16656849, 0.62930436, 0.08619475, 0.01069619],
#         [0.68483583, 0.68336182, 0.46885878, 0.09582986, 0.47783371],
#         [0.55217197, 0.1533125 , 0.72005204, 0.84841322, 0.32240154],
#         [0.06560434, 0.43015267, 0.58446737, 0.50376059, 0.56913726],
#         [0.3027295 , 0.67748418, 0.48325765, 0.85151166, 0.4897189 ],
#         [0.86240988, 0.86917171, 0.01718365, 0.3203474 , 0.99182311],
# ...

# %%
X = [rand(50,20)]

# %%
# !pip install -U seglearn
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 9.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.2 MB 442 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 301 kB 7.3 MB/s eta 0:00:01
# ...

# %%
from seglearn.transform import Segment

# %%
segmenter = Segment()

# %%
newX = segmenter.transform(X)

# %%
newX
# Out:
# (array([], shape=(0, 100, 20), dtype=float64), None, None)

# %%
# !pip install tslearn
# Out:
# ...
#      |████████████████████████████████| 434 kB 3.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.2 MB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.9 MB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 18.4 MB 6.6 MB/s eta 0:00:01
# ...

# %%
from tslearn.utils import to_time_series_dataset
X = to_time_series_dataset([[1, 2, 3, 4], [1, 2, 3], [2, 5, 6, 7, 8, 9]])
# Out:
# /opt/anaconda3/envs/drama/lib/python3.8/site-packages/tslearn/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
X
# Out:
# array([[[ 1.],
#         [ 2.],
#         [ 3.],
#         [ 4.],
#         [nan],
#         [nan]],
#
#        [[ 1.],
#         [ 2.],
#         [ 3.],
#         [nan],
#         [nan],
#         [nan]],
#
#        [[ 2.],
#         [ 5.],
#         [ 6.],
#         [ 7.],
#         [ 8.],
#         [ 9.]]])

# %%
from tslearn.clustering import TimeSeriesKMeans
km = TimeSeriesKMeans(n_clusters=2, metric="dtw")
labels = km.fit_predict(X)
km_bis = TimeSeriesKMeans(n_clusters=2, metric="softdtw")
labels_bis = km_bis.fit_predict(X)
# Out:
# /opt/anaconda3/envs/drama/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/envs/drama/lib/python3.8/site-packages/tslearn/barycenters.py:898: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   X_ = numpy.array([to_time_series(d, remove_nans=True) for d in X_])
# ...

# %%
km_bis
# Out:
# TimeSeriesKMeans(metric='softdtw', n_clusters=2)

# %%
labels_bis
# Out:
# array([0, 0, 1])
